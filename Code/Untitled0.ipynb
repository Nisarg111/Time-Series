# %% [markdown]
# <a href="https://colab.research.google.com/github/Nisarg111/Time-Series/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd

df = yf.download("TSLA")
# df = df.reset_index()
df.plot()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <Axes: xlabel='Date'>

# %%
df_resample = df['Open'].rolling(2).mean()
df_resample
# Out:
# Date
# 2010-06-29           NaN
# 2010-06-30      1.493000
# 2010-07-01      1.693000
# 2010-07-02      1.600000
# 2010-07-06      1.433333
#                  ...
# 2024-05-20    175.555000
# 2024-05-21    176.534996
# 2024-05-22    179.180000
# 2024-05-23    182.325005
# 2024-05-24    178.320000
# Name: Open, Length: 3501, dtype: float64
